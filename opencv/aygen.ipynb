# %%
import cv2 # kütüphane versiyon kontrol
cv2.__version__
# Out:
# '4.4.0'

# %%
import numpy # kütüphane versiyon kontrol
numpy.__version__
# Out:
# '1.18.5'

# %%
import cv2, numpy
print(cv2.__version__)
print(numpy.__version__)
# Out:
# 4.4.0
# 1.18.5

# %%
import cv2 as cv # as'in anlamı ( cv2'i kod içinde cv olarak çağır!) demektir.
import numpy as np
print(cv.__version__)
print(np.__version__)
# Out:
# 4.4.0
# 1.18.5

# %%
# kütüphaneleri import etme
import cv2 as cv

# resim dosyasını okuma
image = cv.imread('pic.png') # dosya uzantısının .png olduğuna dikkat edin!

# resmi görüntüleme
# ilk parametre görüntü penceresinin adı ikinci parametre görüntülemek istediğiniz resim
cv.imshow('image',image) 

# herhangi bir tuşa basıp devam et
cv.waitKey(0) # 0 parametresi herhangi bir tuşa basıldığında devam etmesini sağlar.
cv.destroyAllWindows() # resmi ekrandan kapatır.

# %% [markdown]
# ##### Yukarıdaki kodu çalıştırdığınızda görmeniz gereken::

# %% [markdown]
# ![](l2.png)

# %%
# kütüphaneleri import etme
import numpy as np

my_list = [1,4,1,2,3,4,6]

my_list_numpy = np.array(my_list)

print(my_list)
print(my_list_numpy)
print("\n")
print(type(my_list))
print(type(my_list_numpy))
# Out:
# [1, 4, 1, 2, 3, 4, 6]
# [1 4 1 2 3 4 6]
#
#
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
import datetime

old_time = datetime.datetime.now() # zamanı ölç
my_list = [1,4,1,2,3,4,6]
for i in my_list:
    i += 1
new_time = datetime.datetime.now() # zamanı ölç
new_time - old_time # geçen süre
# Out:
# datetime.timedelta(microseconds=1000)

# %%
import datetime
import numpy as np

old_time = datetime.datetime.now() # zamanı ölç
my_list = [1,4,1,2,3,4,6]
my_list_numpy = np.array(my_list)
my_list_numpy += 1
new_time = datetime.datetime.now() # zamanı ölç
new_time - old_time # geçen süre
# Out:
# datetime.timedelta(microseconds=1008)

# %%
import datetime

old_time = datetime.datetime.now() # zamanı ölç
my_list = list(range(1000))
for i in my_list:
    i += 1
new_time = datetime.datetime.now() # zamanı ölç
new_time - old_time # geçen süre
# Out:
# datetime.timedelta(microseconds=1995)

# %%
import datetime
import numpy as np

old_time = datetime.datetime.now() # zamanı ölç
my_list = list(range(1000))
my_list_numpy = np.array(my_list)
my_list_numpy += 1
new_time = datetime.datetime.now() # zamanı ölç
new_time - old_time # geçen süre
# Out:
# datetime.timedelta(microseconds=992)

# %% [markdown]
# ##### Görüldüğü gibi numpy'in gücü aslında dosyanızın boyutunun artmasıyla ortaya çıkıyor.

# %%
# kütüphaneleri çağırma
import cv2 as cv
import skimage.exposure

image = cv.imread('pic.png') # görüntüyü alma

hist, hist_centers = exposure.histogram(image) # görüntünün histogramını bulma

# --------------- Bu kısma aldırış etmeyin---------------------
fig, axes = plt.subplots(1, 2, figsize=(8, 3))

axes[0].imshow(image, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')
# -------------------------------------------------------------

img_eq = exposure.equalize_hist(image) # histogram eşitleme çalışması

# --------------- Bu kısma aldırış etmeyin---------------------
hist2, hist_centers2 = exposure.histogram(img_eq)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))

axes[0].imshow(img_eq, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers2, hist2, lw=2)
axes[1].set_title('histogram of gray values')
# -------------------------------------------------------------
# Out:
# <ipython-input-80-2e405b242c00>:7: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, hist_centers = exposure.histogram(image)
# C:\Users\cmcvs\anaconda3\lib\site-packages\skimage\exposure\exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)
# <ipython-input-80-2e405b242c00>:16: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist2, hist_centers2 = exposure.histogram(img_eq)
# Text(0.5, 1.0, 'histogram of gray values')

# %%
# kütüphaneleri çağırma
import cv2 as cv
import skimage.exposure

image = cv.imread('redball.jpg') # görüntüyü alma

hist, hist_centers = exposure.histogram(image) # görüntünün histogramını bulma

# --------------- Bu kısma aldırış etmeyin---------------------
fig, axes = plt.subplots(1, 2, figsize=(8, 3))

axes[0].imshow(image, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')
# -------------------------------------------------------------

img_eq = exposure.equalize_hist(image) # histogram eşitleme çalışması

# --------------- Bu kısma aldırış etmeyin---------------------
hist2, hist_centers2 = exposure.histogram(img_eq)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))

axes[0].imshow(img_eq, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers2, hist2, lw=2)
axes[1].set_title('histogram of gray values')
# -------------------------------------------------------------
# Out:
# <ipython-input-82-72f5c9abcf75>:7: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, hist_centers = exposure.histogram(image)
# C:\Users\cmcvs\anaconda3\lib\site-packages\skimage\exposure\exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)
# <ipython-input-82-72f5c9abcf75>:16: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist2, hist_centers2 = exposure.histogram(img_eq)
# Text(0.5, 1.0, 'histogram of gray values')

# %%
# kütüphaneleri import etme
import cv2 as cv

# resim dosyasını okuma
image = cv.imread('pic.png') # dosya uzantısının .png olduğuna dikkat edin!
image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY) # görüntüyü gri tona çevirme

# resmi görüntüleme
# ilk parametre görüntü penceresinin adı ikinci parametre görüntülemek istediğiniz resim
cv.imshow('image',image) 
cv.imshow('image_gray',image_gray) 

# herhangi bir tuşa basıp devam et
cv.waitKey(0) # 0 parametresi herhangi bir tuşa basıldığında devam etmesini sağlar.
cv.destroyAllWindows() # resmi ekrandan kapatır.

# %% [markdown]
# ##### Yukarıdaki kodu çalıştırdığınızda görmeniz gereken::

# %% [markdown]
# ![](l1.png)

# %%
# kütüphaneleri import etme
import cv2 as cv

# resim dosyasını okuma
image = cv.imread('pic.png') # dosya uzantısının .png olduğuna dikkat edin!
image_hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV) # görüntüyü hsv türüne çevirme

# resmi görüntüleme
# ilk parametre görüntü penceresinin adı ikinci parametre görüntülemek istediğiniz resim
cv.imshow('image',image) 
cv.imshow('image_hsv',image_hsv) 

# herhangi bir tuşa basıp devam et
cv.waitKey(0) # 0 parametresi herhangi bir tuşa basıldığında devam etmesini sağlar.
cv.destroyAllWindows() # resmi ekrandan kapatır.

# %% [markdown]
# ![](l3.png)

# %% [markdown]
# # Nedir bu HSV ?
# ##### Kesinlikle bakılmalı  https://py2py.com/we-already-have-rgb-so-why-we-need-hsv/
# https://www.quora.com/Why-use-an-HSV-image-for-color-detection-rather-than-an-RGB-image?share=1
# https://dsp.stackexchange.com/questions/2687/why-do-we-use-the-hsv-colour-space-so-often-in-vision-and-image-processing
# ![](hsv.png)

# %% [markdown]
# ### Şimdi aşağıdaki resimden sarı bölgeleri algılamak isteyelim.
# ![](pic.png)
# ### Bunun için hsv haritasından sarı bölgeyi bulalım.
# ![](jj.png)
# ### Değerlerin (20 ile 45) arasında olduğunu gördünüz. Şimdi kodu inceleyelim.

# %%
# kütühaneleri import etme
import cv2 as cv
import numpy as np

# resmi çağırma
image = cv.imread("pic.png")
# hsv türüne dönüştürme
image_hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV)

# alt ve üst değerileri nasıl yazdığımızı inceleyelim. 40 değerlerini görmezden geliniz.
lower_yellow = np.array([20,40,40])
# Genel olarak son iki değerler 255 alır. Bunu şimdilik görmezden gelin.
upper_yellow = np.array([45,255,255])

# maske oluşturma 
# Belirlediğimiz değerler arasındaki pikselleri beyaz, diğerleri siyah yapar.
mask_blue = cv.inRange(image_hsv,lower_yellow,upper_yellow)

# ekranda gösterme
cv.imshow('image',image)
cv.imshow('image_hsv',image_hsv)
cv.imshow('mask_blue',mask_blue)

# herhangi bir tuş ve çıkış
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# # Notlar buraya kadar ------------------------------------------------------------------------------------------

# %%
from skimage import filters, exposure
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import tkinter as tk 
from tkinter import filedialog 

root = tk.Tk() 
root.withdraw() 
file_path = filedialog.askopenfilename() 

image = cv.imread(file_path)
image_hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV)
#image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

img_eq = exposure.equalize_hist(image)
cv.imshow('image',image)
cv.imshow('img_eq',img_eq)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-71-8039720b87cc> in <module>
#      11
#      12 image = cv.imread(file_path)
# ---> 13 image_hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV)
#      14 #image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
#      15
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-wwma2wne\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
from skimage import exposure
import cv2 as cv
import numpy as np
import tkinter as tk 
from tkinter import filedialog 
import time

root = tk.Tk() 
root.withdraw() 
file_path = filedialog.askopenfilename() 

image = cv.imread(file_path)
image_hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV)

lower_blue = np.array([56,165,70])
upper_blue = np.array([102,255,255])

lower_red = np.array([0,153,95])
upper_red = np.array([7,255,255])

mask_blue = cv.inRange(image_hsv,lower_blue,upper_blue)
mask_red = cv.inRange(image_hsv,lower_red,upper_red)

M = cv.moments(mask_red)


cX = int(M["m10"] / M["m00"])

cY = int(M["m01"] / M["m00"])
cv.circle(image, (cX, cY), 5, (255, 255, 255), -1)
cv.putText(image, "hedef", (cX - 25, cY - 25),cv.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
cv.imshow('image',image)
cv.imshow('image_hsv',image_hsv)
cv.imshow('mask_blue',mask_blue)
cv.imshow('mask_red',mask_red)

cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture("threeball.mp4")

while True:
    _,image = cap.read()
    image_hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV)

    lower_blue = np.array([56,165,70])
    upper_blue = np.array([102,255,255])

    mask_blue = cv.inRange(image_hsv,lower_blue,upper_blue)

    M = cv.moments(mask_blue)

    cX = int(M["m10"] / M["m00"])

    cY = int(M["m01"] / M["m00"])
    cv.circle(image, (cX, cY), 5, (255, 255, 255), -1)
    cv.putText(image, "centroid", (cX - 25, cY - 25),cv.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    cv.imshow('image',image)
    cv.imshow('image_hsv',image_hsv)
    cv.imshow('mask_blue',mask_blue)

    k = cv.waitKey(25)
    if k == 27:
        break
        
cap.release()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-1d9573bcade8> in <module>
#      15     M = cv.moments(mask_blue)
#      16
# ---> 17     cX = int(M["m10"] / M["m00"])
#      18
#      19     cY = int(M["m01"] / M["m00"])
#
# ZeroDivisionError: float division by zero
